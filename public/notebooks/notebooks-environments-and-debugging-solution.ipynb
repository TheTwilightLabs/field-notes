# %% [markdown]
# # Notebooks, environments, and debugging
#
# **Lesson objective:** Complete the practical workflow for notebooks, environments, and debugging.
#
# **Required packages:** Python standard library only
#
# **Expected outcome:** You can explain and reproduce the main result from notebooks, environments, and debugging.
#
# **Troubleshooting:** Restart the kernel and run all cells from the top. Confirm the active environment contains the required packages.

# %% [markdown]
# ## Dataset loading
#
# This lesson does not require an external dataset.

# %% [markdown]
# ## Guided practice
#
# Read each step, predict the result, and run the cell.

# %% [markdown]
# ## Completed solution
#
# The cells below contain one complete, executable solution.

# %%
scores = [72, 84, 91]
score = scores[-1]
print(score)
