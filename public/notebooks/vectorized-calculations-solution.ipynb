# %% [markdown]
# # Vectorized calculations and statistics
#
# **Lesson objective:** Complete the practical workflow for vectorized calculations and statistics.
#
# **Required packages:** numpy
#
# **Expected outcome:** You can explain and reproduce the main result from vectorized calculations and statistics.
#
# **Troubleshooting:** Restart the kernel and run all cells from the top. Confirm the active environment contains the required packages.

# %% [markdown]
# ## Dataset loading
#
# This lesson does not require an external dataset.

# %% [markdown]
# ## Guided practice
#
# Read each step, predict the result, and run the cell.

# %% [markdown]
# ## Completed solution
#
# The cells below contain one complete, executable solution.

# %%
import numpy as np
scores = np.array([72, 84, 91, 63])
standardized = (scores - scores.mean()) / scores.std()
print(standardized.round(2))
