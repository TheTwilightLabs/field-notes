# %% [markdown]
# # Variables, values, and data types
#
# **Lesson objective:** Complete the practical workflow for variables, values, and data types.
#
# **Required packages:** Python standard library only
#
# **Expected outcome:** You can explain and reproduce the main result from variables, values, and data types.
#
# **Troubleshooting:** Restart the kernel and run all cells from the top. Confirm the active environment contains the required packages.

# %% [markdown]
# ## Dataset loading
#
# This lesson does not require an external dataset.

# %% [markdown]
# ## Guided practice
#
# Read each step, predict the result, and run the cell.

# %% [markdown]
# ## Completed solution
#
# The cells below contain one complete, executable solution.

# %%
name = 'Asha'
lessons = 4
score = 88.5
completed = True
print(type(name), type(lessons), type(score), type(completed))
