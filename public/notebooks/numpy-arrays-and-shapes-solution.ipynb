# %% [markdown]
# # NumPy arrays and shapes
#
# **Lesson objective:** Complete the practical workflow for numpy arrays and shapes.
#
# **Required packages:** numpy
#
# **Expected outcome:** You can explain and reproduce the main result from numpy arrays and shapes.
#
# **Troubleshooting:** Restart the kernel and run all cells from the top. Confirm the active environment contains the required packages.

# %% [markdown]
# ## Dataset loading
#
# This lesson does not require an external dataset.

# %% [markdown]
# ## Guided practice
#
# Read each step, predict the result, and run the cell.

# %% [markdown]
# ## Completed solution
#
# The cells below contain one complete, executable solution.

# %%
import numpy as np
features = np.array([[2, 70], [5, 84], [7, 91]])
print(features.shape)
print(features[:, 1])
