# %% [markdown]
# # Select, filter, sort, and group
#
# **Lesson objective:** Complete the practical workflow for select, filter, sort, and group.
#
# **Required packages:** pandas
#
# **Expected outcome:** You can explain and reproduce the main result from select, filter, sort, and group.
#
# **Troubleshooting:** Restart the kernel and run all cells from the top. Confirm the active environment contains the required packages.

# %%
DATASET_PATH = "https://raw.githubusercontent.com/TheTwilightLabs/field-notes/main/public/datasets/sales.csv"
print("Dataset:", DATASET_PATH)

# %% [markdown]
# ## Guided practice
#
# Read each step, predict the result, and run the cell.

# %% [markdown]
# ## Completed solution
#
# The cells below contain one complete, executable solution.

# %%
import pandas as pd
sales = pd.read_csv(DATASET_PATH)
print(sales.groupby('region')['revenue'].sum().sort_values(ascending=False))
