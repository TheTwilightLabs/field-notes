# %% [markdown]
# # Frame and train a first model
#
# **Lesson objective:** Complete the practical workflow for frame and train a first model.
#
# **Required packages:** pandas, scikit-learn
#
# **Expected outcome:** You can explain and reproduce the main result from frame and train a first model.
#
# **Troubleshooting:** Restart the kernel and run all cells from the top. Confirm the active environment contains the required packages.

# %%
DATASET_PATH = "https://raw.githubusercontent.com/TheTwilightLabs/field-notes/main/public/datasets/iris.csv"
print("Dataset:", DATASET_PATH)

# %% [markdown]
# ## Guided practice
#
# Read each step, predict the result, and run the cell.

# %% [markdown]
# ## Completed solution
#
# The cells below contain one complete, executable solution.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
iris = pd.read_csv(DATASET_PATH)
X = iris.drop(columns='species')
y = iris['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
model = LogisticRegression(max_iter=300).fit(X_train, y_train)
print('test accuracy:', round(model.score(X_test, y_test), 3))
