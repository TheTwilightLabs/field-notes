# %% [markdown]
# # Start immediately with Google Colab
#
# **Lesson objective:** Complete the practical workflow for start immediately with google colab.
#
# **Required packages:** Python standard library only
#
# **Expected outcome:** You can explain and reproduce the main result from start immediately with google colab.
#
# **Troubleshooting:** Restart the kernel and run all cells from the top. Confirm the active environment contains the required packages.

# %% [markdown]
# ## Dataset loading
#
# This lesson does not require an external dataset.

# %% [markdown]
# ## Guided practice
#
# Read each step, predict the result, and run the cell.

# %% [markdown]
# ## Completed solution
#
# The cells below contain one complete, executable solution.

# %%
message = 'My first Colab notebook'
print(message)

# %%
import pandas as pd
print('pandas is ready:', pd.__name__)
